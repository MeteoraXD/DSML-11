# %%
import math

print(math.isqrt(4))
# Out:
# 2

# %%
print(math.gcd( 1, 2 , 3))
# Out:
# 1

# %%
print(math.ceil( 92))
# Out:
# 92

# %%
text1 = "hello"
text2 = 'hell"o"'
text3 = "hell'o'"

print(text1)
print(text2)
print(text3)
# Out:
# hello
# hell"o"

# %%
text1 = "Hello My name is Sanjay"
text2 = 'Hello My Name is "Sanjay"'
print(text2)
text3 = "a"
text4 = "b"
print(text3 + text4)
# Out:
# Hello My Name is "Sanjay"
# ab

# %%
print(text1 * 3)
# Out:
# Hello My name is SanjayHello My name is SanjayHello My name is Sanjay

# %%
data = "Python"
data[-6]
# Out:
# 'P'

# %%
#DATA SLICING vairable[start : end : step]
data[1:-1:2]
# Out:
# 'yh'

# %%
data11 = "Hello Python"
data11[1:-1]
# Out:
# 'ello Pytho'

# %%
data3 = "bankai senbonzakura kageyoshi"
print(data3.replace("senbonzakura kageyoshi" , "tensa zangetsu"))
# Out:
# bankai tensa zangetsu

# %%
data3 = "bankai senbonzakura kageyoshi"
print(data3.upper())
# Out:
# BANKAI SENBONZAKURA KAGEYOSHI

# %%
data3 = "bankai senbonzakura kageyoshi"
print(data3.lower())
# Out:
# bankai senbonzakura kageyoshi

# %%
data3 = "bankai senbonzakura kageyoshi"
print(data.join)
# Out:
# <built-in method join of str object at 0xa32de0>

# %%
data3.strip("bankai")
# Out:
# <built-in method strip of str object at 0x7a851e9231b0>

# %%
data4 = "image.png"
data4.endswith("png")
# Out:
# True
