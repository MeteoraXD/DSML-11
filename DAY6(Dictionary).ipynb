# %% [markdown]
# # DICTIONARY

# %%
# Dictionary format
data = {
"id" : 123,
"name" : "John Doe",
"is_active": True,
"roles": ["Admin" , "Editor"],
"contact":{
"email": 'exmaple@email.com',
"phone": '+9779810100000',
"telephone": None,
}
}
print(type(data))
dict({"name":"Sanjay" , "rollno":28})
# Out:
# <class 'dict'>
# {'name': 'Sanjay', 'rollno': 28}

# %%
dict({
    'student1':{
        "name": 'Sanjay',
        'age': 25
    },  
      'student2':{
        "name": 'Ramesh',
        'age': 27
    }
})
# Out:
# {'student1': {'name': 'Sanjay', 'age': '25'},
#  'student2': {'name': 'Ramesh', 'age': '27'}}

# %%
person = {
     'name': 'Ram',
    'country' : 'USA',
    'telephone': 9810100001,
}
print(person)
# Out:
# {'name': 'Ram', 'nepal': 'USA', 'telephone': 9810100001}

# %%
person1 = dict({

     'name': 'Mahesh',
    'country' : 'Nepal',
    'telephone': 9810100001,
})
print(person1)
# Out:
# {'name': 'Mahesh', 'country': 'Nepal', 'telephone': 9810100001}

# %%
# Pair concept
person2 = dict([
    ('name' , 'Rita'),
    ('country' , 'nepal'),
    ('telephone' , 9819191919),
])
person2
# Out:
# {'name': 'Rita', 'country': 'nepal', 'telephone': 9819191919}

# %%
data1 = {
    'name': 'Mahesh',
    'country' : 'Nepal',
    'telephone': 9810100001,
    'phone': 9810100001,
    'address': 9810100001,
    'wahh': 9810100001,
}
data1['name']
# Out:
# 'Mahesh'

# %%
print(data1.keys())
print(data1.values())
print(data1.items())
print(data1.clear())
data1
# Out:
# dict_keys([])
# dict_values([])
# dict_items([])
# None
# {}

# %%
q = {}
print(type(q))
# Out:
# <class 'dict'>

# %%
data3 = {
    'name': 'Mahesh',
    'country' : 'Nepal',
    'telephone': 9810100001,
    'phone': 9810100001,
    'address': 9810100001,
    'wahh': 9810100001,
}
del data3['name']
data3
# Out:
# {'country': 'Nepal',
#  'telephone': 9810100001,
#  'phone': 9810100001,
#  'address': 9810100001,
#  'wahh': 9810100001}

# %%
del data3

# %%
data3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 data3
#
# NameError: name 'data3' is not defined

# %%
data4 = {
    'name': 'Mahesh',
    'country' : 'Nepal',
    'telephone': 9810100001,
    'phone': 9810100001,
    'address': 9810100001,
    'wahh': 9810100001,
}
del data4['country']
data4
# Out:
# {'name': 'Mahesh',
#  'telephone': 9810100001,
#  'phone': 9810100001,
#  'address': 9810100001,
#  'wahh': 9810100001}

# %%
data5 = {
    'name': 'Mahesh',
    'country' : 'Nepal',
    'telephone': 9810100001,
    'phone': 9810100001,
    'address': 9810100001,
    'wahh': 9810100001,
}
data5.pop('name')
data5
# Out:
# {'country': 'Nepal',
#  'telephone': 9810100001,
#  'phone': 9810100001,
#  'address': 9810100001,
#  'wahh': 9810100001}

# %%
data5['name'] = 'sanjay'
data5
# Out:
# {'country': 'Nepal',
#  'telephone': 9810100001,
#  'phone': 9810100001,
#  'address': 9810100001,
#  'wahh': 9810100001,
#  'name': 'sanjay'}

# %%
data5.popitem()
data5
# Out:
# {'country': 'Nepal',
#  'telephone': 9810100001,
#  'phone': 9810100001,
#  'address': 9810100001,
#  'wahh': 9810100001}

# %%
# update()

dict_1 = { 'name' : 'Ram'}
dict_2 = {'roll number' : 32}
dict_1.update(dict_2)
dict1
# Out:
# {'name': 'Ram', 'roll number': 32}

# %%
dict_1 = { 'name' : 'Ram'}
dict_2 = {'roll_number' : 32}
dict_3 = {'country' : 'Nepal'}
dict_4 = {**dict_1 , **dict_2 , **dict_3}
print (dict_1 | dict_2 | dict_3)
dict_4
# Out:
# {'name': 'Ram', 'roll_number': 32, 'country': 'Nepal'}
# {'name': 'Ram', 'roll_number': 32, 'country': 'Nepal'}

# %%
data_5 = { 'name' : 'sanjay' , 'age' : 32 , ' roll_no'  : 43}
print(sorted(data_5))
# Out:
# [' roll_no', 'age', 'name']

# %%
student = { 
    'name' : 'Rama',
    'age' : 23,
    'faculty': 'science',
    'city ' : 'Pokhara'
}

student['phone'] = 9819000001
student['age'] = 25
print(student)
if('email' in student):
    print('true')
else:
        print('false')
# Out:
# {'name': 'Rama', 'age': 25, 'faculty': 'science', 'city ': 'Pokhara', 'phone': 9819000001}
# false

# %%
# Out:
# false
