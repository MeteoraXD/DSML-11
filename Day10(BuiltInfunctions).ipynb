# %%
lst = []

def user_data():
    for i in range(5):
        a = int(input("Enter a number: "))
        lst.append(a)

    return lst

data = user_data()

file = open("index.txt", "w")
file.write(str(data))
file.close()

# %%
file = open("index.txt" , 'r')
file.close()

# %%
# enumumerate

values = [1,2,3,4,5,6,7]
for i in enumerate(values , start=3 ):
    print(i)
# Out:
# (3, 1)
# (4, 2)
# (5, 3)
# (6, 4)
# (7, 5)
# (8, 6)
# (9, 7)

# %%
dictt = {
    "name" : "Sanjay",
    "gender" : "Male",
    "dob" : "2000-10-27",
    "salary" : 1000000
}

for i , (j,k)  in enumerate(dictt.items()):
    print(k)
# Out:
# Sanjay
# Male
# 2000-10-27
# 1000000

# %%
lst = ["name" , "dob","gender" , "salary" ]
lst_2 = ["ram" , " 2020-1-29" , "male" , 20000]
lst_3 = ["laxam" , " 2020-12-29" , "male" , 20001]
lst_4 = ["krishna" , " 2020-10-29" , "male" , 20002]
lst_5 = ["hanuman" , " 2020-11-29" , "male" , 20003]

list(zip(lst,lst_2 , lst_3 , lst_4 , lst_5))

for (i,j) in zip (lst , lst_2):
    print(i,j , sep = ":")
# Out:
# name:ram
# dob: 2020-1-29
# gender:male
# salary:20000

# %%
for i, (k,v) in enumerate(zip(lst,lst_2 , lst_3 , lst_4 , lst_5)):
    print(k,v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 for i, (k,v) in enumerate(zip(lst,lst_2 , lst_3 , lst_4 , lst_5)):
#       2     print(k,v)
#
# ValueError: too many values to unpack (expected 2, got 5)
