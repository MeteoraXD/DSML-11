# %% [markdown]
# # ATM MENU SYSTEM

# %%
balance = 50000

while True:
    print("Welcome to ATM Menu:")
    print("1. Check Balance")
    print("2. Deposit")
    print("3. Exit")

    user_choice = int(input("Enter your choice of Action:"))

    if user_choice == 1:
        print("Your balance is : " , balance)

    elif user_choice == 2:
        deposit_amount = float(input("Enter amount to deposit:"))   
        balance = balance + deposit_amount
        print ("Deposit successful.")
        print("Your new balance is :" , balance)

    elif user_choice == 3:
        print("Thank you for using the ATM")
        break
    else:
        print("Invalid Pin entered. Please try again")
# Out:
# Welcome to ATM Menu:
# 1. Check Balance
# 2. Deposit
# 3. Exit
# Your balance is :  50000
# Welcome to ATM Menu:
# 1. Check Balance
# 2. Deposit
# 3. Exit
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      10
#      11     if user_choice == 1:
#      12         print("Your balance is : " , balance)
#      13
# ---> 14     elif choice == 2:
#      15         deposit_amount = float(input("Enter amount to deposit:"))
#      16         balance = balance + deposit_amount
#      17         print ("Deposit successful.")
#
# NameError: name 'choice' is not defined
