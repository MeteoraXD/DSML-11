# %% [markdown]
# **importing pandas, numpy, matplotlib and seaborn**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **mouting using drive**

# %%
df = pd.read_csv("survey_student.csv")
df.columns =["Date","Gender","Grade","Year","Faculty","Average","Accomodation","Monthly_Allowance","Scholarship_Bulsary","Study_Hours","Party_Socializing","Drinks_Consumed","Class_Missed","Modules_Failed","Romantic_Relationship","Alcohol_Consumption_Allowed","Relationship_Parents"]
df.sample(10)
# Out:
#                           Date  Gender  Grade          Year  \
# 111  2024/03/07 6:04:29 pm EET  Female   73.0      2nd Year
# 153  2024/03/07 6:59:23 pm EET  Female   85.0           NaN
# 351  2024/03/10 2:48:41 pm EET  Female   76.0           NaN
# 303  2024/03/08 9:50:48 am EET    Male   67.0      1st Year
# 24   2024/03/07 5:16:35 pm EET  Female   78.0      1st Year
# 387  2024/03/11 3:12:20 pm EET  Female   86.0      1st Year
# 226  2024/03/07 9:27:52 pm EET  Female   82.0      2nd Year
# 220  2024/03/07 9:14:34 pm EET  Female   78.0      2nd Year
# 138  2024/03/07 6:26:53 pm EET    Male   70.0  Postgraduate
# 340  2024/03/09 9:53:21 am EET    Male   76.0      1st Year
#
#                             Faculty  Average  \
# 111  Economic & Management Sciences     62.0
# 153          Arts & Social Sciences      NaN
# 351  Economic & Management Sciences     60.0
# 303  Economic & Management Sciences     30.0
# 24   Economic & Management Sciences     76.0
# ...

# %% [markdown]
# # **Removing unnecessary columns**

# %% [markdown]
# **Dropping unnecessary columns**

# %%
df.drop(columns = ["Party_Socializing","Drinks_Consumed","Romantic_Relationship","Alcohol_Consumption_Allowed","Relationship_Parents"],inplace = True)

# %%
df.columns
# Out:
# Index(['Date', 'Gender', 'Grade', 'Year', 'Faculty', 'Average', 'Accomodation',
#        'Monthly_Allowance', 'Scholarship_Bulsary', 'Study_Hours',
#        'Class_Missed', 'Modules_Failed'],
#       dtype='object')

# %% [markdown]
# **Checking the dtypes of each columns**

# %%
df.dtypes
# Out:
# Date                    object
# Gender                  object
# Grade                  float64
# Year                    object
# Faculty                 object
# Average                float64
# Accomodation            object
# Monthly_Allowance       object
# Scholarship_Bulsary     object
# Study_Hours             object
# Class_Missed            object
# Modules_Failed          object
# dtype: object

# %% [markdown]
# **Converting the Datetime into date only**

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df["Year"] = df["Date"].dt.year

df.Year.sample(5)
# Out:
# /tmp/ipykernel_20384/4168586279.py:1: FutureWarning: Parsed string "2024/03/07 5:12:01 pm EET" included an un-recognized timezone "EET". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
# /tmp/ipykernel_20384/4168586279.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
# ...

# %% [markdown]
# **Dropping Date column**

# %%
df.drop(columns = ["Date"],inplace = True)
df.columns
# Out:
# Index(['Gender', 'Grade', 'Year', 'Faculty', 'Average', 'Accomodation',
#        'Monthly_Allowance', 'Scholarship_Bulsary', 'Study_Hours',
#        'Class_Missed', 'Modules_Failed'],
#       dtype='object')

# %% [markdown]
# # **Handling Null Values**

# %% [markdown]
# **Checking null values**

# %%
df.isna().sum()
# Out:
# Gender                  2
# Grade                   7
# Year                    0
# Faculty                 7
# Average                86
# Accomodation           23
# Monthly_Allowance      31
# Scholarship_Bulsary     8
# Study_Hours             3
# Class_Missed            3
# Modules_Failed          3
# dtype: int64

# %% [markdown]
# **Filling null values of Gender using Mode**

# %%
df.Gender.fillna(df["Gender"].mode()[0],inplace = True)
# Out:
# /tmp/ipykernel_20384/2490187954.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Gender.fillna(df["Gender"].mode()[0],inplace = True)

# %% [markdown]
# **Filling null values of Grade**

# %%
df.Grade.fillna(df["Grade"].mean(),inplace = True)
# Out:
# /tmp/ipykernel_20384/1817325729.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Grade.fillna(df["Grade"].mean(),inplace = True)

# %% [markdown]
# **Filling null values of Faculty**

# %%
df.Faculty.fillna(df["Faculty"].mode()[0],inplace = True)
# Out:
# /tmp/ipykernel_20384/819885497.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Faculty.fillna(df["Faculty"].mode()[0],inplace = True)

# %% [markdown]
# **Counting different or unique values of accomodation and filling with mode**

# %%
df.Accomodation.value_counts()
# Out:
# Accomodation
# Private accommodation/ stay with family/friends    335
# Non-private accommodation ie. Res                   48
# Name: count, dtype: int64

# %%
df.Accomodation.fillna(df["Accomodation"].mode()[0],inplace = True)
# Out:
# /tmp/ipykernel_20384/2965411295.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Accomodation.fillna(df["Accomodation"].mode()[0],inplace = True)

# %% [markdown]
# **Filling monthly allowance**

# %%
df.Monthly_Allowance.unique()
# Out:
# array(['R 4001- R 5000', 'R 7001 - R 8000', 'R 6001 - R 7000',
#        'R 5001 - R 6000', nan, 'R 8000+'], dtype=object)

# %%
df.Monthly_Allowance.fillna(df["Monthly_Allowance"].mode()[0],inplace =True)
# Out:
# /tmp/ipykernel_20384/4167491968.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Monthly_Allowance.fillna(df["Monthly_Allowance"].mode()[0],inplace =True)

# %% [markdown]
# **Filling Scholarship and Bulsary**

# %%
df.Scholarship_Bulsary.value_counts()
# Out:
# Scholarship_Bulsary
# No                     352
# Yes (NSFAS, etc...)     46
# Name: count, dtype: int64

# %%
df.Scholarship_Bulsary.fillna(df["Scholarship_Bulsary"].mode()[0],inplace = True)
# Out:
# /tmp/ipykernel_20384/620545314.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Scholarship_Bulsary.fillna(df["Scholarship_Bulsary"].mode()[0],inplace = True)

# %% [markdown]
# **Filling na of Study_Hours**

# %%
df.Study_Hours.value_counts()
# Out:
# Study_Hours
# 8+       114
# 5-Mar    105
# 3-Jan     83
# 8-May     81
# 0         20
# Name: count, dtype: int64

# %%
df["Study_Hours"] = df["Study_Hours"].fillna(df["Study_Hours"].mode()[0])

# %% [markdown]
# **Handling Class missed**

# %%
df.Class_Missed.value_counts()
# Out:
# Class_Missed
# 0     214
# 1      75
# 2      63
# 4+     27
# 3      24
# Name: count, dtype: int64

# %%
df.Class_Missed.fillna(df["Class_Missed"].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_20384/2756158103.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Class_Missed.fillna(df["Class_Missed"].mode()[0],inplace=True)

# %% [markdown]
# **Handling Modules_Failed**

# %%
df.Modules_Failed.value_counts()
# Out:
# Modules_Failed
# 0     263
# 1      58
# 2      31
# 4+     27
# 3      24
# Name: count, dtype: int64

# %%
df.Modules_Failed.fillna(df["Modules_Failed"].mode()[0],inplace = True)
# Out:
# /tmp/ipykernel_20384/2628923908.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Modules_Failed.fillna(df["Modules_Failed"].mode()[0],inplace = True)

# %% [markdown]
# # **Handling Outliers**

# %%
numeric_columns = df.select_dtypes(include = ["int32","float64"]).columns

# %%
for col in numeric_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    count = ((df[col] < lower_limit) | (df[col] > upper_limit)).sum()
    print(f"{col}: {count} outliers")
# Out:
# Grade: 8 outliers
# Year: 0 outliers
# Average: 2 outliers

# %% [markdown]
# **Using log(1 + x) to handle outliers**

# %%
df[["Grade","Average"]] = np.log1p(df[["Grade","Average"]])

# %%
df[["Grade","Average"]]
# Out:
#         Grade   Average
# 0    4.343805  4.290459
# 1    4.499810  4.330733
# 2    4.343805  4.025352
# 3    4.499810  4.442651
# 4    4.317488  3.970292
# ..        ...       ...
# 401  4.317488       NaN
# 402  4.304065  4.077537
# 403  4.465908       NaN
# 404  4.454347       NaN
# 405  4.394449  4.158883
#
# [406 rows x 2 columns]

# %% [markdown]
# # **Encoding**

# %% [markdown]
# **Year, Gender and Scholarship**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df["Gender"] = le.fit_transform(df["Gender"])

# %%
df["Scholarship_Bulsary"] = le.fit_transform(df["Scholarship_Bulsary"])

# %%
df["Year"] = le.fit_transform(df["Year"])

# %%
df[["Year","Gender","Scholarship_Bulsary"]]
# Out:
#      Year  Gender  Scholarship_Bulsary
# 0       0       0                    0
# 1       0       1                    1
# 2       0       1                    0
# 3       0       1                    0
# 4       0       0                    0
# ..    ...     ...                  ...
# 401     0       0                    0
# 402     0       0                    1
# 403     0       0                    0
# 404     0       1                    0
# 405     0       0                    0
#
# [406 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'Grade', 'Year', 'Faculty', 'Average', 'Accomodation',
#        'Monthly_Allowance', 'Scholarship_Bulsary', 'Study_Hours',
#        'Class_Missed', 'Modules_Failed'],
#       dtype='object')

# %% [markdown]
# **Faculty, Accomodation**

# %%
df = pd.get_dummies(df,columns = ["Faculty","Accomodation"])
df[["Faculty","Accomodation"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20384/2176400406.py in <cell line: 0>()
# ----> 1 df = pd.get_dummies(df,columns = ["Faculty","Accomodation"])
#       2 df[["Faculty","Accomodation"]]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...
