# %% [markdown]
# # Day 43
# - PCA , LDA
# PCA = Unsupervised
# LDA = Supervised
#
# **PCA**
# - only input data hercha
# - examples price of houses
#
# size of house, no of floor , bathroom , etc (can be more features of house)
#
# feature badi huni vayesi complexity badxa ani accuracy ghatxa
#
# feature kam vaye bhaney
# accuracy badxa complexity ghatxa
#
# steps for PCA
# - mean of every feature
# - covriance matrix
# - eigen values and vecctors
# - choose principle components
# - projected data onto principle component
#
#
# **LDA**
# - LDA is supervised learning primarily used to dimessionality reduction and classification tasks
# - The goal is to find a linear combination of features that maximize the seperation of class while minnimizing the spread (variance) within each class.
#         - maximizing mean difference
#         - minimizing within class scatter
#
# Steps for LDA
#  - Calculate the Mean vectors for each class
#  - compute the covariance of each class
#  - compute the within class scatter matrix
#  - compute the between class scatter matrix
#  - find eigen vlaues and choose top eigen value
#  - find the eigen vectors
#  - find the dot product of data points with eigen vector

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = sns.load_dataset('titanic')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
X = df[['pclass', 'age', 'sibsp', 'parch', 'fare']]

# %%
scalar = StandardScaler()
X = X.fillna(X.mean())
X_Scaled = scalar.fit_transform(X)

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(X_Scaled)

# %%
pca_df = pd.DataFrame(data=x_pca, columns=['PC1', 'PC2'])
pca_df.head()
# Out:
#         PC1       PC2
# 0  1.150803 -0.069191
# 1 -1.758606  0.142885
# 2  0.889439 -0.718299
# 3 -1.448581  0.081721
# 4  0.574460 -0.939013

# %%
pca_2 = PCA(n_components=3)

# %%
x_pca_1 = pca_2.fit_transform(X_Scaled)

# %%
pca_df_1 = pd.DataFrame(data=x_pca_1, columns=['PC1', 'PC2', 'PC3'])
pca_df_1.head()
# Out:
#         PC1       PC2       PC3
# 0  1.150803 -0.069191 -0.203607
# 1 -1.758606  0.142885 -0.095648
# 2  0.889439 -0.718299 -0.210813
# 3 -1.448581  0.081721 -0.157688
# 4  0.574460 -0.939013  0.344915

# %%
# Applying LDA

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
y= df['survived']

lda = LinearDiscriminantAnalysis(n_components=1)
x_lda = lda.fit_transform(X_Scaled, y)

# %%
lda_df = pd.DataFrame(data=x_lda, columns=['LD1'])

# %%
lda_df.head()
# Out:
#         LD1
# 0 -0.782780
# 1  1.109609
# 2 -0.712100
# 3  1.157592
# 4 -1.092297

# %% [markdown]
# - Class work
#  ** Load Iris dataset and perform PCA**
#  - Standardize the features.
#  - Reduce the dataset from 4D to 2 principal components.
#  - Calculate the explained variance ratio.
#  - Plot the transformed data using different colors for each species.

# %%
df_iris = sns.load_dataset('iris')

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X_Iris = df_iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
scalar = StandardScaler()
X_Iris = X_Iris.fillna(X_Iris.mean())
X_Iris_Scaled = scalar.fit_transform(X_Iris)

# %%
pca = PCA(n_components=2)
x_iris_pca = pca.fit_transform(X_Iris_Scaled)

# %%
pca_df = pd.DataFrame(data=x_iris_pca, columns=['PC1', 'PC2'])
pca_df.head()
# Out:
#         PC1       PC2
# 0 -2.264703  0.480027
# 1 -2.080961 -0.674134
# 2 -2.364229 -0.341908
# 3 -2.299384 -0.597395
# 4 -2.389842  0.646835

# %%
y= df_iris['petal_length']

lda = LinearDiscriminantAnalysis(n_components=1)
x_lda = lda.fit_transform(X_Iris_Scaled, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 4
#       1 y= df_iris['petal_length']
#       2
#       3 lda = LinearDiscriminantAnalysis(n_components=1)
# ----> 4 x_lda = lda.fit_transform(X_Iris_Scaled, y)
#
# File ~/dsml-11/.venv/lib/python3.14/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/dsml-11/.venv/lib/python3.14/site-packages/sklearn/base.py:972, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     969     return self.fit(X, **fit_params).transform(X)
#     970 else:
#     971     # fit method of arity 2 (supervised transformation)
# --> 972     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/dsml-11/.venv/lib/python3.14/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/dsml-11/.venv/lib/python3.14/site-packages/sklearn/discriminant_analysis.py:669, in LinearDiscriminantAnalysis.fit(self, X, y)
#     664 xp, _ = get_namespace(X)
#     666 X, y = validate_data(
#     667     self, X, y, ensure_min_samples=2, dtype=[xp.float64, xp.float32]
#     668 )
# --> 669 self.classes_ = unique_labels(y)
#     670 n_samples, n_features = X.shape
#     671 n_classes = self.classes_.shape[0]
#
# File ~/dsml-11/.venv/lib/python3.14/site-packages/sklearn/utils/multiclass.py:111, in unique_labels(ys_types, *ys)
#     109 _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     110 if not _unique_labels:
# --> 111     raise ValueError("Unknown label type: %s" % repr(ys))
#     113 if is_array_api_compliant and not _is_numpy_namespace(xp):
#     114     # non-NumPy array API inputs do not allow for mixed dtypes
#     115     unique_ys = xp.concat([_unique_labels(y, xp=xp) for y in ys])
#
# ValueError: Unknown label type: (array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1]),)
