# %% [markdown]
# # DAY 31
# - Outlier Handling
# - Data Manipulation
# - Problem Domain
# - Solution Domain

# %%
import pandas as pd
titanic_df = pd.read_csv("titanic.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#  Deleting columns
 
# titanic_df.drop("PassengerId",axis=1, inplace=True)

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic_df.drop([0,2,5] , axis=0 , inplace=False).head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 1  female  38.0      1      0  PC 17599  71.2833   C85        C
# 3  female  35.0      1      0    113803  53.1000  C123        S
# 4    male  35.0      0      0    373450   8.0500   NaN        S
# 6    male  54.0      0      0     17463  51.8625   E46        S
# 7    male   2.0      3      1    349909  21.0750   NaN        S

# %%
# Inserting Column

last_names = [name.split(",")[0] for name in titanic_df["Name"]]
titanic_df["last_names"] = last_names

titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#   last_names
# 0     Braund
# 1    Cumings
# 2  Heikkinen
# 3   Futrelle
# 4      Allen

# %%
# Inserting into rows

titanic_df.loc[900,:] = [0,3, "Sanjay , Pahari" , "male" , 22.0 , 1.0 ,0, "A5 3423" , 7.5 , 'C43' , "S" , "Pahari" ]

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                            Braund, Mr. Owen Harris
# 1         1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     3.0                             Heikkinen, Miss. Laina
# 3         1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     3.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 887       1.0     1.0                       Graham, Miss. Margaret Edith
# 888       0.0     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0     1.0                              Behr, Mr. Karl Howell
# 890       0.0     3.0                                Dooley, Mr. Patrick
# 900       0.0     3.0                                    Sanjay , Pahari
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
new_rows = pd.DataFrame([
    [0, 3, "Sanjay, Pahari", "male", 22.0, 1.0, 0, "A5 3423", 7.5, "C43", "S", "Pahari"],
    [1, 1, "Meera, Thapa", "female", 30.0, 0.0, 1, "PC 9999", 50.0, "B12", "C", "Thapa"],
], columns=titanic_df.columns)

titanic_df = pd.concat([titanic_df, new_rows], ignore_index=True)

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                            Braund, Mr. Owen Harris
# 1         1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     3.0                             Heikkinen, Miss. Laina
# 3         1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     3.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 889       1.0     1.0                              Behr, Mr. Karl Howell
# 890       0.0     3.0                                Dooley, Mr. Patrick
# 891       0.0     3.0                                    Sanjay , Pahari
# 892       0.0     3.0                                     Sanjay, Pahari
# 893       1.0     1.0                                       Meera, Thapa
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
# Handling NAN or NULL values

titanic_df.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         687
# Embarked        2
# last_names      0
# dtype: int64

# %%
# titanic_df_filter = titanic_df.dropna(subset="Embarked",axis=0 , how="all",ignore_index=True)
# titanic_df_filter.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S
# 1  female  38.0    1.0    0.0          PC 17599  71.2833   C85        C
# 2  female  26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0    1.0    0.0            113803  53.1000  C123        S
# 4    male  35.0    0.0    0.0            373450   8.0500   NaN        S
#
#   last_names
# 0     Braund
# 1    Cumings
# 2  Heikkinen
# 3   Futrelle
# 4      Allen

# %%
# titanic_df_filter = titanic_df.dropna(subset="Cabin",axis=0 , how="all",ignore_index=True)

# %%
titanic_df_filter.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2       0.0     1.0                            McCarthy, Mr. Timothy J
# 3       1.0     3.0                    Sandstrom, Miss. Marguerite Rut
# 4       1.0     1.0                           Bonnell, Miss. Elizabeth
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked last_names
# 0  female  38.0    1.0    0.0  PC 17599  71.2833   C85        C    Cumings
# 1  female  35.0    1.0    0.0    113803  53.1000  C123        S   Futrelle
# 2    male  54.0    0.0    0.0     17463  51.8625   E46        S   McCarthy
# 3  female   4.0    1.0    1.0   PP 9549  16.7000    G6        S  Sandstrom
# 4  female  58.0    0.0    0.0    113783  26.5500  C103        S    Bonnell

# %%
print(titanic_df.Age.mean())
# Out:
# 29.69911764705882

# %%
titanic_df.Age.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
mean_age = titanic_df.Age.mean()
titanic_df["Age"].fillna(mean_age,axis=0,inplace=True)
# Out:
# /tmp/ipykernel_68337/1137920142.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   titanic_df["Age"].fillna(mean_age,axis=0,inplace=True)
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# ...

# %%
titanic_df.Age.plot.hist(bins= 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Imputation of age w.r.t gender provided
titanic_df_2 =  pd.read_csv("titanic.csv")

# %%
titanic_df_2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mean_ages = titanic_df_2.groupby("Sex")["Age"].transform("mean")

# %%
titanic_df_2["Age"].fillna(mean_ages,inplace=True)
# Out:
# /tmp/ipykernel_68337/4021339144.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   titanic_df_2["Age"].fillna(mean_ages,inplace=True)
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    27.915709
# 889    26.000000
# ...

# %%
titanic_df_2.Age.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_df_2.Cabin = titanic_df_2.Cabin.notna().astype(int)

# %%
titanic_df_2.Age.plot.box()
# Out:
# <Axes: >

# %%
titles = titanic_df['Name'].str.split(",")
titanic_df['Title'] = titles.str[1].str.strip().str.split(' ').str[0]
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr.
# 1      0          PC 17599  71.2833   C85        C   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.
# 3      0            113803  53.1000  C123        S   Mrs.
# ...

# %%
titanic_df[titanic_df.duplicated(subset="Sex")]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
titanic_df.drop_duplicates(inplace=True)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr.
# 1      0          PC 17599  71.2833   C85        C   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.
# 3      0            113803  53.1000  C123        S   Mrs.
# ...
