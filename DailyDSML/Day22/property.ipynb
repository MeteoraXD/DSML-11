# %% [markdown]
# # Property

# %%
class Student:
    def __init__(self,name):
        self.name = name

    @property
    def name(self):
        return self.name

# %%
std = Student("sanjay)
std.name

# %%
class Student1:
    def __init__(self,age):
        self.age = age

    @property
    def age(self):
        return self.age 

    @age.setter
    def
