# %% [markdown]
# # DOCSTRING

# %%
def sum(a,b):
    '''Adding two numbers
    '''
    return(a+b)

print(sum.__doc__)
# Out:
# Adding two numbers

# %%
help(sum)
# Out:
# Help on function sum in module __main__:
#
# sum(a, b)
#     Adding two numbers

# %%
def area_of_rectangle(l,b):
    '''Area of the rectangle has length(l) and breadth(b)
    '''
    return(l*b)

print(area_of_rectangle.__doc__)
print(area_of_rectangle(4,6))
# Out:
# Area of the rectangle has length(l) and breadth(b)
#
# 24

# %%
help(area_of_rectangle)
# Out:
# Help on function area_of_rectangle in module __main__:
#
# area_of_rectangle(l, b)
#     Area of the rectangle has length(l) and breadth(b)

# %%
def string_add(*args):
    return(args)

print(string_add("Welcome" , "to" , "skillshikshya"))
# Out:
# ('Welcome', 'to', 'skillshikshya')

# %%
def data3(n, *args , **kwargs):
    print(n)
    print(args)
    print(kwargs)

data3(1,2,3,4,5,6 ,s=1 , s1=2)
# Out:
# 1
# (2, 3, 4, 5, 6)
# {'s': 1, 's1': 2}

# %%
i=0
dict_1 = {}
n = int(input('Enter the number of pizzas'))
if n > 0:
    for i in range(n):
        types_of_pizza = str(input('What type of Pizzas would you like'))
        i+=1
name_1= input('Enter your name')
address_1 = input('enter your address')
  
def pizza_order(n, *args , **kwargs):
    print(n)
    print(*args)
    print(**kwargs)

pizza_order(n,types_of_pizza,name = name_1 , address = address_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 16
#      12     address_1 = input('enter your address')
#      13     print(name_1)
#      14     print(address_1)
#      15
# ---> 16 pizza_order(n,types_of_pizza,name = name_1 , address = address_1)
#      17
#
# NameError: name 'n' is not defined
