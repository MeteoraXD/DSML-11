# %% [markdown]
# # File Handling

# %%
f = open("new_file.txt")
f
# Out:
# <_io.TextIOWrapper name='new_file.txt' mode='r' encoding='UTF-8'>

# %%
txt = f.read()
txt
# Out:
# 'This is Sparta.\nmy name is maximus decimus meridius'

# %%
f.close()

# %%
txt
# Out:
# 'This is Sparta'

# %%
with open("new_file.txt", "a") as f:
  f.write("Bankai!")

# %%
with open("new_file.txt") as f:
    print(f.read())
# Out:
# kdgaighfbbhjjnjsadn
# BankaiBankai!Bankai!Bankai!

# %%
with open("new_file.txt", "w") as f:
    f.write("Barasinghe")

# %%
import os

os.remove("new_file.txt")

# %%
import json
json_string = '{"name": "Alice", "age": 30, "city": "New York"}'

data_dict = json.loads(json_string)
print(data_dict)

type(data_dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}
# dict

# %%
import json

person = {"name": "Alice", "age": 30, "city": "New York"}

data_json = json.dumps(person,indent=4)
print(data_json)
type(data_json)
# Out:
# {
#     "name": "Alice",
#     "age": 30,
#     "city": "New York"
# }
# str
